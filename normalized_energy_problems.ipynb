# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 500)

# %%
excel_file = pd.ExcelFile('bps_energy_consumption_2011_2012.xlsx')

raw_2011 = excel_file.parse('2011 Raw')
norm_2011 = excel_file.parse('2011 Normalized ')

raw_2012 = excel_file.parse('2012 Raw')
norm_2012 = excel_file.parse('2012 Normalized')

# %% [markdown]
# ## Sector/Subsector Names changing

# %%
raw_2012[raw_2012['Operation Name'] =='KG-King Campus -Greenhouse']
# Out:
#       Organization Name                           Sector Name Subsector Name  \
# 10877    Seneca College  Post-secondary Educational Institute        College
# 10918    Seneca College  Post-Secondary Educational Institute        College
# 10919    Seneca College  Post-Secondary Educational Institute        College
#
#                    Operation Name  \
# 10877  KG-King Campus -Greenhouse
# 10918  KG-King Campus -Greenhouse
# 10919  KG-King Campus -Greenhouse
#
#                                       Operation Type                Address  \
# 10877  Administrative offices and related facilities  13991 Dufferin Street
# 10918              Classrooms and related facilities  13991 Dufferin Street
# 10919                                   Laboratories  13991 Dufferin Street
#
#             City     Zip  Total Floor Area          Unit  \
# 10877  King City  L7B1B3            2990.38  Square feet
# 10918  King City  L7B1B3            1201.48  Square feet
# ...

# %%
norm_2012[norm_2012['Operation Name'] =='KG-King Campus -Greenhouse']
# Out:
#       Organization Name                           Sector Name Subsector Name  \
# 12634    Seneca College  Post-secondary Educational Institute        College
# 12635    Seneca College  Post-secondary Educational Institute        College
# 16683    Seneca College                          Municipality   Municipality
#
#                    Operation Name                Address  eWh/HDD/ft^2  \
# 12634  KG-King Campus -Greenhouse  13991 Dufferin Street     13.766086
# 12635  KG-King Campus -Greenhouse  13991 Dufferin Street     13.766086
# 16683  KG-King Campus -Greenhouse  13991 Dufferin Street     13.766086
#
#        Energy Intensity (ekWh/ML)
# 12634                         NaN
# 12635                         NaN
# 16683                         NaN

# %% [markdown]
# ## Records being duplicated

# %%
raw_2012[raw_2012['Operation Name'] == 'Belmont Fire Hall']
# Out:
#                   Organization Name   Sector Name Subsector Name  \
# 7763  Municipality of Central Elgin  Municipality   Municipality
#
#          Operation Name                                     Operation Type  \
# 7763  Belmont Fire Hall  Fire stations and associated offices and facil...
#
#               Address     City     Zip  Total Floor Area          Unit  \
# 7763  206 Caesar Road  Belmont  N0L1B0               2800  Square feet
#
#       Average Hours per week  Annual Flow   Electricity Electricity Unit  \
# 7763                      10             0     12283.94              kWh
#
#       Natural Gas Natural Gas2  Fuel Oil 1 & 2 Fuel Oil 1 & 2 Unit  \
# 7763       4298.1  Cubic Meter               0               Litre
#
#       Fuel Oil 4 &6 Fuel Oil 4 &6 Unit  Propane Propane Unit  Coal Quantity  \
# 7763              0              Litre        0        Litre              0
#
#          Coal Unit  Wood         Wood3  District Heating  \
# ...

# %%
norm_2012[norm_2012['Operation Name'] == 'Belmont Fire Hall']
# Out:
#                   Organization Name Sector Name Subsector Name  \
# 629   Municipality of Central Elgin   Municipal   Municipality
# 3663  Municipality of Central Elgin   Municipal   Municipality
#
#          Operation Name          Address  eWh/HDD/ft^2  \
# 629   Belmont Fire Hall  206 Caesar Road      6.280685
# 3663  Belmont Fire Hall  206 Caesar Road      6.280685
#
#       Energy Intensity (ekWh/ML)
# 629                          NaN
# 3663                         NaN

# %% [markdown]
# ## Some records that I assume should have normalized values, don't

# %%
raw_2012[raw_2012['Operation Name'] == 'Kaneff Tower (485)']
# Out:
#       Organization Name                           Sector Name Subsector Name  \
# 17921   York University  Post-Secondary Educational Institute    University
#
#            Operation Name                                 Operation Type  \
# 17921  Kaneff Tower (485)  Administrative offices and related facilities
#
#                  Address     City     Zip  Total Floor Area            Unit  \
# 17921  4700 Keele Street  Toronto  M3J1P3           10719.04  Square meters
#
#        Average Hours per week  Annual Flow   Electricity Electricity Unit  \
# 17921                      60             0      1626957              kWh
#
#        Natural Gas Natural Gas2  Fuel Oil 1 & 2 Fuel Oil 1 & 2 Unit  \
# 17921       113669  Cubic Meter               0               Litre
#
#        Fuel Oil 4 &6 Fuel Oil 4 &6 Unit  Propane Propane Unit  Coal Quantity  \
# 17921              0              Litre        0        Litre              0
#
# ...

# %%
norm_2012[norm_2012['Operation Name'] == 'Kaneff Tower (485)']
# Out:
# Empty DataFrame
# Columns: [Organization Name, Sector Name, Subsector Name, Operation Name, Address, eWh/HDD/ft^2, Energy Intensity (ekWh/ML)]
# Index: []

# %% [markdown]
# ## Some records are duplicated

# %%
raw_2011[raw_2011['Operation Name'] == 'Accolade Building East (412)']
# Out:
#      Organization Name                             Sector Name SubSector Name  \
# 4451   York University  Post-Secondary Educational Institution     University
#
#                     Operation Name                     Operation Type  \
# 4451  Accolade Building East (412)  Classrooms and related facilities
#
#                 Address     City ZIP/Postal Code  Total Floor Area  \
# 4451  4700 Keele Street  Toronto         M3J 1P3          22799.12
#
#               Unit1  Annual Flow  Average Hours Per Week  Electricity Unit2  \
# 4451  Square meters          NaN                   106.5      2945043   kWh
#
#       Natural Gas Unit3  Fuel Oil 1 & 2 Unit4  Fuel Oil 4 & 6 Unit5  Propane  \
# 4451          NaN   NaN             NaN   NaN             NaN   NaN      NaN
#
#      Unit6  Coal Unit7  Wood Unit8  District Heat  \
# 4451   NaN   NaN   NaN   NaN   NaN     5076.42044
#
#                                 Unit9  Renewable1  Emission Factor1  \
# ...

# %%
norm_2011[norm_2011['Operation Name'] == 'Accolade Building East (412)']
# Out:
#       Organization Name                             Sector Name  \
# 15537   York University  Post-Secondary Educational Institution
# 15574   York University  Post-Secondary Educational Institution
#
#       SubSector Name                Operation Name            Address  \
# 15537     University  Accolade Building East (412)  4700 Keele Street
# 15574     University  Accolade Building East (412)  4700 Keele Street
#
#        eWh/HDD/ft^2  Energy Intensity (ekWh/ML)
# 15537       5.28713                         NaN
# 15574       5.28713                         NaN

# %% [markdown]
# ## Some records are duplicated with different normalized values

# %%
raw_2011[raw_2011['Operation Name'] == 'Technology Enhanced Learning (483)']
# Out:
#      Organization Name                             Sector Name SubSector Name  \
# 4499   York University  Post-Secondary Educational Institution     University
#
#                           Operation Name                     Operation Type  \
# 4499  Technology Enhanced Learning (483)  Classrooms and related facilities
#
#                 Address     City ZIP/Postal Code  Total Floor Area  \
# 4499  4700 Keele Street  Toronto         M3J 1P3          32017.61
#
#               Unit1  Annual Flow  Average Hours Per Week  Electricity Unit2  \
# 4499  Square meters          NaN                     168      3464060   kWh
#
#       Natural Gas        Unit3  Fuel Oil 1 & 2 Unit4  Fuel Oil 4 & 6 Unit5  \
# 4499        13687  Cubic meter             NaN   NaN             NaN   NaN
#
#       Propane Unit6  Coal Unit7  Wood Unit8  District Heat  \
# 4499      NaN   NaN   NaN   NaN   NaN   NaN     3366.25388
#
#                                 Unit9  Renewable1  Emission Factor1  \
# ...

# %%
norm_2011[norm_2011['Operation Name'] == 'Technology Enhanced Learning (483)']
# Out:
#       Organization Name                             Sector Name  \
# 15534   York University  Post-Secondary Educational Institution
# 15571   York University  Post-Secondary Educational Institution
#
#       SubSector Name                      Operation Name            Address  \
# 15534     University  Technology Enhanced Learning (483)  4700 Keele Street
# 15571     University  Technology Enhanced Learning (483)  4700 Keele Street
#
#        eWh/HDD/ft^2  Energy Intensity (ekWh/ML)
# 15534      3.924383                         NaN
# 15571      4.498432                         NaN

# %% [markdown]
# ## Some close-together buildings seem to have a large difference in their HDD

# %%
raw_york_2011[raw_york_2011['Operation Name'] == 'Behavioural Science Building (358)']
# Out:
#      Organization Name                             Sector Name SubSector Name  \
# 4456   York University  Post-Secondary Educational Institution     University
#
#                           Operation Name  \
# 4456  Behavioural Science Building (358)
#
#                                      Operation Type            Address  \
# 4456  Administrative offices and related facilities  4700 Keele Street
#
#          City ZIP/Postal Code  Total Floor Area          Unit1  Annual Flow  \
# 4456  Toronto         M3J 1P3           8405.81  Square meters          NaN
#
#       Average Hours Per Week  Electricity Unit2  Natural Gas Unit3  \
# 4456                    72.5      1217005   kWh          NaN   NaN
#
#       Fuel Oil 1 & 2 Unit4  Fuel Oil 4 & 6 Unit5  Propane Unit6  Coal Unit7  \
# 4456             NaN   NaN             NaN   NaN      NaN   NaN   NaN   NaN
#
#       Wood Unit8  District Heat                            Unit9  Renewable1  \
# ...

# %%
norm_york_2011[norm_york_2011['Operation Name'] == 'Behavioural Science Building (358)']
# Out:
#       Organization Name                             Sector Name  \
# 15519   York University  Post-Secondary Educational Institution
#
#       SubSector Name                      Operation Name            Address  \
# 15519     University  Behavioural Science Building (358)  4700 Keele Street
#
#        eWh/HDD/ft^2  Energy Intensity (ekWh/ML)
# 15519     17.813251                         NaN

# %%
(62.956768*1000.)/17.813251
# Out:
# 3534.2660359975835

# %%
raw_york_2011[raw_york_2011['Operation Name'] == 'Winters College (368)']
# Out:
#      Organization Name                             Sector Name SubSector Name  \
# 4507   York University  Post-Secondary Educational Institution     University
#
#              Operation Name                                 Operation Type  \
# 4507  Winters College (368)  Administrative offices and related facilities
#
#                 Address     City ZIP/Postal Code  Total Floor Area  \
# 4507  4700 Keele Street  Toronto         M3J 1P3           6897.26
#
#               Unit1  Annual Flow  Average Hours Per Week  Electricity Unit2  \
# 4507  Square meters          NaN                      85      1663006   kWh
#
#       Natural Gas Unit3  Fuel Oil 1 & 2 Unit4  Fuel Oil 4 & 6 Unit5  Propane  \
# 4507          NaN   NaN             NaN   NaN             NaN   NaN      NaN
#
#      Unit6  Coal Unit7  Wood Unit8  District Heat  \
# 4507   NaN   NaN   NaN   NaN   NaN     19511.0268
#
#                                 Unit9  Renewable1  Emission Factor1  \
# ...

# %%
norm_york_2011[norm_york_2011['Operation Name'] == 'Winters College (368)']
# Out:
#       Organization Name                             Sector Name  \
# 15525   York University  Post-Secondary Educational Institution
#
#       SubSector Name         Operation Name            Address  eWh/HDD/ft^2  \
# 15525     University  Winters College (368)  4700 Keele Street     23.044362
#
#        Energy Intensity (ekWh/ML)
# 15525                         NaN

# %%
(98.627309 * 1000.)/23.044362
# Out:
# 4279.888894298744

# %% [markdown]
# ## The join keys leaves some ambiguity

# %%
raw_2011[raw_2011['Operation Name'] == 'Glengarry Memorial Hospital']
# Out:
#                            Organization Name      Sector Name SubSector Name  \
# 3777  Alexandria Glengarry Memorial Hospital  Public Hospital  Acute/Chronic
# 3778  Alexandria Glengarry Memorial Hospital  Public Hospital  Acute/Chronic
#
#                    Operation Name  \
# 3777  Glengarry Memorial Hospital
# 3778  Glengarry Memorial Hospital
#
#                                      Operation Type               Address  \
# 3777          Facilities used for hospital purposes  20260 County Road 43
# 3778  Administrative offices and related facilities  20260 County Road 43
#
#             City ZIP/Postal Code  Total Floor Area        Unit1  Annual Flow  \
# 3777  Alexandria         K0C 1A0             51016  Square feet          NaN
# 3778  Alexandria         K0C 1A0              3953  Square feet          NaN
#
#       Average Hours Per Week  Electricity Unit2  Natural Gas        Unit3  \
# 3777                     168      1428141   kWh       234846  Cubic meter
# ...

# %%
norm_2011[norm_2011['Operation Name'] == 'Glengarry Memorial Hospital']
# Out:
#                         Organization Name      Sector Name SubSector Name  \
# 2  Alexandria Glengarry Memorial Hospital  Public Hospital  Acute/Chronic
# 3  Alexandria Glengarry Memorial Hospital  Public Hospital  Acute/Chronic
#
#                 Operation Name               Address  eWh/HDD/ft^2  \
# 2  Glengarry Memorial Hospital  20260 County Road 43     18.506644
# 3  Glengarry Memorial Hospital  20260 County Road 43     18.506758
#
#    Energy Intensity (ekWh/ML)
# 2                         NaN
# 3                         NaN
